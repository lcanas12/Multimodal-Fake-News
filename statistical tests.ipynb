# %%
from scipy.stats import f_oneway, tukey_hsd, ttest_ind
import numpy as np

# %%
bert_f1 = [0.7276686690533498, 0.7267858101398319, 0.7334526338951117, 0.7256632913574843, 0.7332229871901449, \
           0.7323976687624518, 0.7229272402656022, 0.7272739165129575, 0.7236745710429922, 0.7289374126871753, \
           0.7229677506497144, 0.7222599257634967, 0.7235031597933701, 0.7271884346959122, 0.729079207920792, \
           0.730464078826893, 0.7369384959261662, 0.7321436860498272, 0.7270603216237004, 0.7219786267619772, \
           0.7244909301363509, 0.7392344309443637, 0.7168487605560525, 0.725516046495665, 0.7278861841675912, \
           0.7303603031356241, 0.730773031487221, 0.736306802198402, 0.7271827473970726, 0.7292179475397187]
roberta_f1 = [0.7518059198809633, 0.741393164875593, 0.7390996464222226, 0.7427674084709261, 0.7408310817060364, \
              0.7502143144634255, 0.7520267955695962, 0.7398699329293286, 0.7385248458092265, 0.7484146985894882, \
              0.7446220389957083, 0.747462345896208, 0.7507444938475856, 0.745694702648345, 0.7454823199439047, \
              0.7487783487916573, 0.7447167562299141, 0.7464499692581401, 0.7412207875082208, 0.7508286588475268, \
              0.7498225893079926, 0.7490251072888858, 0.7518270935728106, 0.7427674084709261, 0.7297960333514619, \
              0.7525445187809203, 0.7500118848729338, 0.7309345010655872, 0.7520824605502026, 0.7520824605502026]
xlnet_f1 = [0.7504748939259864, 0.7633777239709443, 0.7572422530249447, 0.7552808928471251, 0.7568881611820161, \
            0.7417472767758632, 0.7419276061256355, 0.7584715871405292, 0.7457578305995145, 0.7395478949139433, \
            0.7552088076164223, 0.7522241690775979, 0.7664633095508909, 0.7541742413770018, 0.7501123028652781, \
            0.7515848701268559, 0.7486673015527029, 0.7623233662001058, 0.7493141117714496, 0.7492125293261287, \
            0.7360651886767022, 0.7507861028250571, 0.7420453692136504, 0.7393680648617024, 0.7525080724535078, \
            0.7565539756524475, 0.7403444840083679, 0.7519085661823199, 0.744331947885315, 0.7378136452790085]

# %%
f_oneway(bert_f1, roberta_f1, xlnet_f1)
# Out:
# F_onewayResult(statistic=98.43837722615562, pvalue=4.549250238276823e-23)

# %%
text_results = tukey_hsd(bert_f1, roberta_f1, xlnet_f1)

# %%
print(text_results)
# Out:
# Tukey's HSD Pairwise Group Comparisons (95.0% Confidence Interval)
# Comparison  Statistic  p-value  Lower CI  Upper CI
#  (0 - 1)     -0.018     0.000    -0.022    -0.014
#  (0 - 2)     -0.022     0.000    -0.026    -0.018
#  (1 - 0)      0.018     0.000     0.014     0.022
#  (1 - 2)     -0.004     0.028    -0.008    -0.000
#  (2 - 0)      0.022     0.000     0.018     0.026
#  (2 - 1)      0.004     0.028     0.000     0.008

# %%
vgg16_f1 = [0.5751012228043453, 0.5610396999483445, 0.5570071290207809, 0.5626205618686586, 0.5632727543572174, \
            0.5678942066920616, 0.5684946115850921, 0.5393778439499257, 0.5666229117037195, 0.5707852359063921, \
            0.5783095503597276, 0.5888913276084392, 0.5498190260310032, 0.5643807746216998, 0.5713512557481429, \
            0.5503577353397527, 0.5694952587010531, 0.5486830291490581, 0.5452502999236558, 0.557631927837734, \
            0.5653423982971423, 0.5673151538479831, 0.566100566100566, 0.549844818993249, 0.5583826405818051, \
            0.5593175754387283, 0.5667290934107935, 0.5707433420744001, 0.5486324477378156, 0.5648870426788701]

vgg19_f1 = [0.5593336130618352, 0.560045577628917, 0.5744201717653045, 0.5612407787616565, 0.5797172513864872, \
            0.5613385402639375, 0.5692912955677385, 0.5682283688258167, 0.5758254581424306, 0.5649055445599804, \
            0.5485432843262832, 0.5458900092051463, 0.5430054007859642, 0.5641800116811322, 0.5354765633108751, \
            0.549268566342455, 0.5530932828913553, 0.5593175754387283, 0.5819698427975618, 0.5541586243200562, \
            0.5519724091941567, 0.6006897434878412, 0.5704521922432246, 0.5406194913120121, 0.5725341508013337, \
            0.5309769296968092, 0.5730245460018442, 0.5545828458613631, 0.5492323778311609, 0.5711736991616434]

xception_f1 = [0.5927470486328159, 0.6032874931581828, 0.6084608387746484, 0.6045846113685309, 0.5967812249415537, \
               0.6012558444023506, 0.592849681119938, 0.5929377549267529, 0.5814558721663271, 0.585165172182142, \
               0.6003586722822272, 0.5736535567044041, 0.5975746793131467, 0.5956138747476948, 0.5905968520903413, \
               0.5933059156170821, 0.5856003522849593, 0.5955675704817909, 0.5969907575867841, 0.5964187488210376, \
               0.5833616019110308, 0.6013216944921571, 0.5994785392858704, 0.5917393147427981, 0.6035447470088564, \
               0.5918380132566503, 0.5974287191515656, 0.6015821276374728, 0.5887985040012682, 0.5981299271830054]

# %%
f_oneway(vgg16_f1, vgg19_f1, xception_f1)
# Out:
# F_onewayResult(statistic=82.85998874585634, pvalue=7.149340975203372e-21)

# %%
img_results = tukey_hsd(vgg16_f1, vgg19_f1, xception_f1)
print(img_results)
# Out:
# Tukey's HSD Pairwise Group Comparisons (95.0% Confidence Interval)
# Comparison  Statistic  p-value  Lower CI  Upper CI
#  (0 - 1)      0.002     0.846    -0.005     0.009
#  (0 - 2)     -0.032     0.000    -0.039    -0.025
#  (1 - 0)     -0.002     0.846    -0.009     0.005
#  (1 - 2)     -0.034     0.000    -0.041    -0.027
#  (2 - 0)      0.032     0.000     0.025     0.039
#  (2 - 1)      0.034     0.000     0.027     0.041

# %%
ttest_ind(vgg16_f1, xception_f1)
# Out:
# Ttest_indResult(statistic=-13.52262795178818, pvalue=1.3933773897749616e-19)

# %%
ttest_ind(vgg19_f1, xception_f1)
# Out:
# Ttest_indResult(statistic=-11.023593755856187, pvalue=7.41074972285042e-16)

# %%
vggface_f1 = [0.5671423357631016, 0.5476881386732873, 0.5468394822702665, 0.5748443287543384, 0.5747042023663811, \
              0.5524874775898192, 0.5309225880133075, 0.5638657428872963, 0.5592964978630508, 0.5484653465346534, \
              0.5334588619858801, 0.5377049128046734, 0.5430913358342194, 0.5562470007275654, 0.5577883522042758, \
              0.5610234716346787, 0.5462465915437432, 0.5414186205262135, 0.533407859817501, 0.537609874526354, \
              0.5473879220509948, 0.5507326884398047, 0.5472995262326723, 0.5423919086921333, 0.5391459361561911, \
              0.5436647904940588, 0.5536085875247425, 0.5517191235201068, 0.5596572198198776, 0.563327814157928]

# %%
ttest_ind(vgg16_f1, vggface_f1)
# Out:
# Ttest_indResult(statistic=4.177147339545019, pvalue=0.00010054647485998091)

# %%
xception_block13_f1 = [0.5953692150293888, 0.6078064554508542, 0.606658691667683, 0.5951528573804338, 0.5954712018207109,\
                       0.587416730586844, 0.6059388501163178, 0.5992976885871981, 0.5954123315628842, 0.5988290505018651, \
                       0.6011705862851648, 0.6015642374056487, 0.591378769654603, 0.5999951271805867, 0.6065491823037592, \
                       0.5966916163385642, 0.6012254758323403, 0.5904227977205236, 0.5961263351983723, 0.5963210378545842, \
                       0.5960455201475787, 0.595101852865598, 0.5989380939555999, 0.6004932622093488, 0.592345813581119, \
                       0.6053259567176068, 0.5887073237274048, 0.5974287191515656, 0.5933208489388265, 0.6014951102674244]
xception_block12_f1 = [0.6068823153328959, 0.6021407697805521, 0.6009734943615502, 0.6008793823254849, 0.6021145654026739, \
                       0.6012988977590749, 0.6064456011824433, 0.5999115110574912, 0.5989610050457476, 0.5973068906776288, \
                       0.6013258541560429, 0.6011249536894587, 0.6046225308170041, 0.6056112761410776, 0.5992976885871981, \
                       0.5935563368145315, 0.605554803539126, 0.6047310162326136, 0.5978287125258327, 0.600609942005914, \
                       0.6077758634770873, 0.6004646761511525, 0.6024986608311734, 0.6041119151408771, 0.6049714804512626, \
                       0.6031310916179338, 0.5962539834490055, 0.6014951102674244, 0.6003701775980884, 0.6077251701200397]
xception_block9_f1 = [0.5807314088547413, 0.5887442479972652, 0.5866912754627133, 0.594865231819319, 0.58672320248725, \
                      0.5918292762513868, 0.583213708393926, 0.5936109049324123, 0.5941686197113606, 0.5952720009175013, \
                      0.596594427244582, 0.5923411106177983, 0.580105156037992, 0.5840496434021614, 0.5852100967656405, \
                      0.590910874769436, 0.5847575657428827, 0.5979148880789124, 0.5893067831691646, 0.5820086943486733, \
                      0.5905279455498667, 0.5994545872606813, 0.5838110790140985, 0.5858462326619512, 0.5903206358261591, \
                      0.5884937734856938, 0.6019373214017145, 0.5918096291357474, 0.580149938778579, 0.590897388399445]

# %%
f_oneway(xception_f1, xception_block13_f1, xception_block12_f1, xception_block9_f1)
# Out:
# F_onewayResult(statistic=25.760347880221616, pvalue=7.636823002325421e-13)

# %%
img_tuned_results = tukey_hsd(xception_f1, xception_block13_f1, xception_block12_f1, xception_block9_f1)
print(img_tuned_results)
# Out:
# Tukey's HSD Pairwise Group Comparisons (95.0% Confidence Interval)
# Comparison  Statistic  p-value  Lower CI  Upper CI
#  (0 - 1)     -0.003     0.143    -0.007     0.001
#  (0 - 2)     -0.007     0.000    -0.011    -0.003
#  (0 - 3)      0.005     0.003     0.001     0.009
#  (1 - 0)      0.003     0.143    -0.001     0.007
#  (1 - 2)     -0.004     0.035    -0.008    -0.000
#  (1 - 3)      0.009     0.000     0.005     0.012
#  (2 - 0)      0.007     0.000     0.003     0.011
#  (2 - 1)      0.004     0.035     0.000     0.008
#  (2 - 3)      0.013     0.000     0.009     0.016
#  (3 - 0)     -0.005     0.003    -0.009    -0.001
#  (3 - 1)     -0.009     0.000    -0.012    -0.005
#  (3 - 2)     -0.013     0.000    -0.016    -0.009
